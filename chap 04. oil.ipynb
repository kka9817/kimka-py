# %%
from selenium import webdriver
from time import sleep

# %%
driver = webdriver.Chrome('C:/Users/kimka/driver/chromedriver.exe')
driver.get("http://www.opinet.co.kr/searRgSelect.do")

# %%
gu_list_raw = driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")
gu_list = gu_list_raw.find_elements_by_tag_name("option")

# %%
gu_names = [option.get_attribute("value") for option in gu_list]
gu_names.remove('')
gu_names
# Out:
# ['강남구',
#  '강동구',
#  '강북구',
#  '강서구',
#  '관악구',
#  '광진구',
#  '구로구',
#  '금천구',
#  '노원구',
#  '도봉구',
#  '동대문구',
#  '동작구',
#  '마포구',
#  '서대문구',
#  '서초구',
#  '성동구',
#  '성북구',
#  '송파구',
#  '양천구',
#  '영등포구',
#  '용산구',
#  '은평구',
#  '종로구',
#  '중구',
#  '중랑구']

# %%
si_list_raw = driver.find_element_by_xpath("""//*[@id="SIDO_NM0"]""")
si_list = si_list_raw.find_elements_by_tag_name("option")
        
si_names = [option.get_attribute("value") for option in si_list]
si_names.remove("")
si_names
# Out:
# ['서울특별시',
#  '부산광역시',
#  '대구광역시',
#  '인천광역시',
#  '광주광역시',
#  '대전광역시',
#  '울산광역시',
#  '세종특별자치시',
#  '경기도',
#  '강원도',
#  '충청북도',
#  '충청남도',
#  '전라북도',
#  '전라남도',
#  '경상북도',
#  '경상남도',
#  '제주특별자치도']

# %%
import time
from tqdm import tqdm_notebook


for gu in tqdm_notebook(gu_names):    
    driver = webdriver.Chrome('C:/Users/kimka/driver/chromedriver.exe')
    driver.get("http://www.opinet.co.kr/searRgSelect.do")
    
    #서울시 설정
    si_list_raw = driver.find_element_by_xpath("""//*[@id="SIDO_NM0"]""")
    si_list = si_list_raw.find_elements_by_tag_name("option")
    
    si_names = [option.get_attribute("value") for option in si_list]
    si_names.remove("")

    element_si = driver.find_element_by_id("SIDO_NM0")
    element_si.send_keys(si_names[0])
    
    time.sleep(1)
    
    #시군구 설정
    gu_list_raw = driver.find_element_by_xpath("""//*[@id="SIGUNGU_NM0"]""")
    gu_list = gu_list_raw.find_elements_by_tag_name("option")
    
    gu_names = [option.get_attribute("value") for option in gu_list]
    gu_names.remove('')

    element = driver.find_element_by_id("SIGUNGU_NM0")
    element.send_keys(gu)
    
    
    xpath = """//*[@id="searRgSelect"]"""
    element_sel_gu = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(1)
    
    xpath = """//*[@id="glopopd_excel"]"""
    element_get_excel = driver.find_element_by_xpath(xpath).click()
    
    time.sleep(3)
    
    driver.close()
# Out:
# HBox(children=(IntProgress(value=0, max=25), HTML(value='')))

# %%
import pandas as pd
from glob import glob

# %%
glob("C:/Users/kimka/Python/ch 4/지역*.xls")
# Out:
# ['C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (1).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (10).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (11).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (12).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (13).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (14).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (15).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (16).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (17).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (18).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (19).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (2).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (20).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (21).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (22).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (23).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (24).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (3).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (4).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (5).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (6).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (7).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (8).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (9).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소).xls']

# %%
station_files = glob("C:/Users/kimka/Python/ch 4/지역*.xls")
station_files
# Out:
# ['C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (1).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (10).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (11).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (12).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (13).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (14).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (15).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (16).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (17).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (18).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (19).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (2).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (20).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (21).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (22).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (23).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (24).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (3).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (4).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (5).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (6).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (7).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (8).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소) (9).xls',
#  'C:/Users/kimka/Python/ch 4\\지역_위치별(주유소).xls']

# %%
len(station_files)
# Out:
# 25

# %%
tmp_raw = []

for file_name in station_files:
    tmp = pd.read_excel(file_name, header=2)
    tmp_raw.append(tmp)
    
station_raw = pd.concat(tmp_raw)

# %%
station_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 510 entries, 0 to 41
# Data columns (total 10 columns):
# 지역       510 non-null object
# 상호       510 non-null object
# 주소       510 non-null object
# 상표       510 non-null object
# 전화번호     510 non-null object
# 셀프여부     510 non-null object
# 고급휘발유    510 non-null object
# 휘발유      510 non-null object
# 경유       510 non-null object
# 실내등유     510 non-null object
# dtypes: object(10)
# memory usage: 43.8+ KB

# %%
station_raw.head()
# Out:
#       지역                상호                          주소      상표         전화번호  \
# 0  서울특별시            동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)   GS칼텍스  02-426-5372
# 1  서울특별시            구천면주유소       서울 강동구 구천면로 357 (암사동)  현대오일뱅크  02-441-0536
# 2  서울특별시    GS칼텍스㈜직영 신월주유소      서울 강동구 양재대로 1323 (성내동)   GS칼텍스  02-475-2600
# 3  서울특별시  주)지유에너지직영 오렌지주유소    서울특별시 강동구  성안로 102 (성내동)   SK에너지  02-484-6165
# 4  서울특별시           방아다리주유소        서울 강동구 동남로 811 (명일동)   SK에너지  02-442-5145
#
#   셀프여부 고급휘발유   휘발유    경유  실내등유
# 0    Y     -  1328  1230     -
# 1    N     -  1357  1276     -
# 2    N  1666  1365  1265  1000
# 3    N     -  1397  1297  1131
# 4    Y     -  1398  1298  1040

# %%
stations = pd.DataFrame({'Oil_store' : station_raw['상호'], 
                        '주소' : station_raw['주소'],
                        '가격' : station_raw['휘발유'],
                        '셀프' : station_raw['셀프여부'],
                        '상표' : station_raw['상표']})
stations.head()
# Out:
#           Oil_store                          주소    가격 셀프      상표
# 0            동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)  1328  Y   GS칼텍스
# 1            구천면주유소       서울 강동구 구천면로 357 (암사동)  1357  N  현대오일뱅크
# 2    GS칼텍스㈜직영 신월주유소      서울 강동구 양재대로 1323 (성내동)  1365  N   GS칼텍스
# 3  주)지유에너지직영 오렌지주유소    서울특별시 강동구  성안로 102 (성내동)  1397  N   SK에너지
# 4           방아다리주유소        서울 강동구 동남로 811 (명일동)  1398  Y   SK에너지

# %%
stations['구'] = [eachAddress.split()[1] for eachAddress in stations['주소']]
stations.head()
# Out:
#           Oil_store                          주소    가격 셀프      상표    구
# 0            동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)  1328  Y   GS칼텍스  강동구
# 1            구천면주유소       서울 강동구 구천면로 357 (암사동)  1357  N  현대오일뱅크  강동구
# 2    GS칼텍스㈜직영 신월주유소      서울 강동구 양재대로 1323 (성내동)  1365  N   GS칼텍스  강동구
# 3  주)지유에너지직영 오렌지주유소    서울특별시 강동구  성안로 102 (성내동)  1397  N   SK에너지  강동구
# 4           방아다리주유소        서울 강동구 동남로 811 (명일동)  1398  Y   SK에너지  강동구

# %%
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '서울특별시', '성북구',
#        '송파구', '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구',
#        '강서구', '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '특별시', '강남구'],
#       dtype=object)

# %%
len(stations['구'].unique())
# Out:
# 27

# %%
stations[stations['구'] == '서울특별시']
# Out:
#          Oil_store                           주소    가격 셀프     상표      구
# 11  SK네트웍스(주)효진주유소  1 서울특별시 성동구 동일로 129 (성수동2가)  1499  N  SK에너지  서울특별시

# %%
stations.loc[stations['구'] == '서울특별시', '구'] = '성동구'
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '특별시', '강남구'],
#       dtype=object)

# %%
len(stations['구'].unique())
# Out:
# 26

# %%
stations[stations['구'] == '특별시']
# Out:
#   Oil_store                        주소    가격 셀프     상표    구
# 6     서현주유소  서울 특별시 도봉구 방학로 142 (방학동)  1328  Y  S-OIL  특별시

# %%
stations.loc[stations['구'] == '특별시', '구'] = '도봉구'
stations['구'].unique()
# Out:
# array(['강동구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '강북구', '용산구', '은평구', '종로구', '중구', '중랑구', '강서구',
#        '관악구', '광진구', '구로구', '금천구', '노원구', '도봉구', '강남구'], dtype=object)

# %%
len(stations['구'].unique())
# Out:
# 25

# %%
stations[stations['가격']=='-']
# Out:
#             Oil_store                         주소 가격 셀프      상표    구
# 11       (주)승지 염리동주유소       서울 마포구 백범로 126 (염리동)  -  N  현대오일뱅크  마포구
# 12              서강주유소       서울 마포구 독막로 134 (창전동)  -  N   SK에너지  마포구
# 13             망원동주유소      서울 마포구 월드컵로 119 (망원동)  -  N   SK에너지  마포구
# 22      KR누리(주) 종암주유소   서울특별시 성북구  종암로 145 (종암동)  -  N   SK에너지  성북구
# 23              현대주유소     서울 양천구 남부순환로 372 (신월동)  -  Y   S-OIL  양천구
# 24  SK네트웍스(주) SKOK주유소  서울특별시 양천구  안양천로 1179 (목동)  -  N   SK에너지  양천구
# 17       대성산업(주)대성주유소       서울 은평구 통일로 642 (녹번동)  -  N   GS칼텍스  은평구
# 40              삼성주유소       서울 강남구 삼성로 521 (삼성동)  -  N   SK에너지  강남구
# 41              동우주유소  서울특별시 강남구  봉은사로 311 (논현동)  -  N   SK에너지  강남구

# %%
stations = stations[stations['가격'] != '-']
stations.head()
# Out:
#           Oil_store                          주소    가격 셀프      상표    구
# 0            동서울주유소  서울특별시 강동구  천호대로 1456 (상일동)  1328  Y   GS칼텍스  강동구
# 1            구천면주유소       서울 강동구 구천면로 357 (암사동)  1357  N  현대오일뱅크  강동구
# 2    GS칼텍스㈜직영 신월주유소      서울 강동구 양재대로 1323 (성내동)  1365  N   GS칼텍스  강동구
# 3  주)지유에너지직영 오렌지주유소    서울특별시 강동구  성안로 102 (성내동)  1397  N   SK에너지  강동구
# 4           방아다리주유소        서울 강동구 동남로 811 (명일동)  1398  Y   SK에너지  강동구

# %%
stations['가격'] = [float(value) for value in stations['가격']]

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 501 entries, 0 to 39
# Data columns (total 6 columns):
# Oil_store    501 non-null object
# 주소           501 non-null object
# 가격           501 non-null float64
# 셀프           501 non-null object
# 상표           501 non-null object
# 구            501 non-null object
# dtypes: float64(1), object(5)
# memory usage: 27.4+ KB

# %%
stations.reset_index(inplace = True)
del stations['index']

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 6 columns):
# Oil_store    501 non-null object
# 주소           501 non-null object
# 가격           501 non-null float64
# 셀프           501 non-null object
# 상표           501 non-null object
# 구            501 non-null object
# dtypes: float64(1), object(5)
# memory usage: 23.6+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

path = "C:/Windows/Fonts/malgun.ttf"

from matplotlib import font_manager, rc

if platform.system() == 'Darwin' : 
    rc('font', family = 'AppleGothic')
elif platform.system() == 'Windows' :
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family = font_name)
else : 
    print("Unknown system... sorry~~")

# %%
stations.boxplot(column = '가격', by = '셀프', figsize = (12,8))

# %%
plt.figure(figsize = (12,8))
sns.boxplot(x = '상표', y = '가격', hue = '셀프', data = stations, palette = 'Set3')
plt.show()

# %%
plt.figure(figsize = (12,8))
sns.boxplot(x = '상표', y = '가격', data = stations, palette = 'Set3')
sns.swarmplot(x = '상표', y = '가격', data = stations, color = '.6')
plt.show()

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)

# %%
stations.sort_values(by = '가격', ascending = False).head(10)
# Out:
#           Oil_store                         주소      가격 셀프     상표    구
# 305           서남주유소       서울 중구 통일로 30 (봉래동1가)  2040.0  N  SK에너지   중구
# 500         뉴서울(강남)       서울 강남구 언주로 716 (논현동)  1998.0  N  SK에너지  강남구
# 304           필동주유소   서울특별시 중구  퇴계로 196 (필동2가)  1979.0  N  GS칼텍스   중구
# 293  (주)대양씨앤씨 사직주유소        서울 종로구 사직로 65 (사직동)  1978.0  N  GS칼텍스  종로구
# 153           삼선주유소           서울 성북구  창경궁로 324  1975.0  N  S-OIL  성북구
# 303     SC(주) 역전주유소  서울특별시 중구  퇴계로 15 (남대문로5가)  1969.0  N  GS칼텍스   중구
# 302           장충주유소     서울 중구 장충단로 202 (장충동1가)  1969.0  N  SK에너지   중구
# 301           초동주유소        서울시 중구 마른내로 31 (초동)  1969.0  N  GS칼텍스   중구
# 114           양재주유소      서울 서초구 바우뫼로 178 (양재동)  1969.0  N  SK에너지  서초구
# 267            에너비스       서울 용산구 한남대로 82 (한남동)  1968.0  N  SK에너지  용산구

# %%
stations.sort_values(by = '가격', ascending = True).head(10)
# Out:
#                Oil_store                          주소      가격 셀프      상표    구
# 268                수색뉴타운    서울특별시 은평구  수색로 350 (수색동)  1285.0  Y   GS칼텍스  은평구
# 269               타이거주유소        서울 은평구 수색로 188 (증산동)  1285.0  Y   SK에너지  은평구
# 270    (주)명연에너지 수색훼미리주유소        서울 은평구 수색로 236 (수색동)  1285.0  Y  현대오일뱅크  은평구
# 76              만남의광장주유소  서울 서초구 양재대로12길 73-71 (원지동)  1294.0  Y  알뜰(ex)  서초구
# 271                다회주유소        서울 은평구 증산로 441 (신사동)  1294.0  Y   S-OIL  은평구
# 322  KH에너지(주)직영 KH외발산주유소              서울 강서구 방화대로 30  1295.0  Y   SK에너지  강서구
# 415                구광주유소   서울특별시 금천구  서부샛길 674 (가산동)  1295.0  N   S-OIL  금천구
# 323            강서오곡셀프주유소     서울특별시 강서구 벌말로 254 (오곡동)  1297.0  Y   SK에너지  강서구
# 306       (주)자연에너지 대창주유소        서울 중랑구 동일로 636 (면목동)  1297.0  N  현대오일뱅크  중랑구
# 443     SK네트웍스(주)도봉행복주유소    서울특별시 도봉구  도봉로 941 (도봉동)  1299.0  Y   SK에너지  도봉구

# %%
import numpy as np
gu_data = pd.pivot_table(stations, index = ['구'], values = ['가격'], aggfunc = np.mean)
gu_data.head()
# Out:
#               가격
# 구
# 강남구  1598.475000
# 강동구  1472.117647
# 강북구  1341.692308
# 강서구  1371.228571
# 관악구  1402.055556

# %%
geo_path = '02. skorea_municipalities_geo_simple.json'
geo_str = json.load (open(geo_path, encoding = 'utf-8'))

map = folium.Map(location = [37.5502, 126.982], zoom_start = 10.5, tiles = 'Stamen Toner')

map.choropleth(geo_data = geo_str,
               data = gu_data,
               columns=[gu_data.index, '가격'],
               fill_color='PuRd', #PuRd, YlGnBu
               key_on='feature.id')
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
oil_price_top10 = stations.sort_values(by = '가격', ascending = False).head(10)
oil_price_top10
# Out:
#           Oil_store                         주소      가격 셀프     상표    구
# 305           서남주유소       서울 중구 통일로 30 (봉래동1가)  2040.0  N  SK에너지   중구
# 500         뉴서울(강남)       서울 강남구 언주로 716 (논현동)  1998.0  N  SK에너지  강남구
# 304           필동주유소   서울특별시 중구  퇴계로 196 (필동2가)  1979.0  N  GS칼텍스   중구
# 293  (주)대양씨앤씨 사직주유소        서울 종로구 사직로 65 (사직동)  1978.0  N  GS칼텍스  종로구
# 153           삼선주유소           서울 성북구  창경궁로 324  1975.0  N  S-OIL  성북구
# 303     SC(주) 역전주유소  서울특별시 중구  퇴계로 15 (남대문로5가)  1969.0  N  GS칼텍스   중구
# 302           장충주유소     서울 중구 장충단로 202 (장충동1가)  1969.0  N  SK에너지   중구
# 301           초동주유소        서울시 중구 마른내로 31 (초동)  1969.0  N  GS칼텍스   중구
# 114           양재주유소      서울 서초구 바우뫼로 178 (양재동)  1969.0  N  SK에너지  서초구
# 267            에너비스       서울 용산구 한남대로 82 (한남동)  1968.0  N  SK에너지  용산구

# %%
oil_price_bottom10 = stations.sort_values(by = '가격', ascending = True).head(10)
oil_price_bottom10
# Out:
#                Oil_store                          주소      가격 셀프      상표    구
# 268                수색뉴타운    서울특별시 은평구  수색로 350 (수색동)  1285.0  Y   GS칼텍스  은평구
# 269               타이거주유소        서울 은평구 수색로 188 (증산동)  1285.0  Y   SK에너지  은평구
# 270    (주)명연에너지 수색훼미리주유소        서울 은평구 수색로 236 (수색동)  1285.0  Y  현대오일뱅크  은평구
# 76              만남의광장주유소  서울 서초구 양재대로12길 73-71 (원지동)  1294.0  Y  알뜰(ex)  서초구
# 271                다회주유소        서울 은평구 증산로 441 (신사동)  1294.0  Y   S-OIL  은평구
# 322  KH에너지(주)직영 KH외발산주유소              서울 강서구 방화대로 30  1295.0  Y   SK에너지  강서구
# 415                구광주유소   서울특별시 금천구  서부샛길 674 (가산동)  1295.0  N   S-OIL  금천구
# 323            강서오곡셀프주유소     서울특별시 강서구 벌말로 254 (오곡동)  1297.0  Y   SK에너지  강서구
# 306       (주)자연에너지 대창주유소        서울 중랑구 동일로 636 (면목동)  1297.0  N  현대오일뱅크  중랑구
# 443     SK네트웍스(주)도봉행복주유소    서울특별시 도봉구  도봉로 941 (도봉동)  1299.0  Y   SK에너지  도봉구

# %%
gmap_key = "AIzaSyBCZiBga8-X9goKYMItyl0jistNVnqiz00"
gmaps = googlemaps.Client(key = gmap_key)

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_top10.index):
    try:
        tmp_add = oil_price_top10['주소'][n].split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        tmp_loc = tmp_map[0]['geometry']
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
    
oil_price_top10['lat'] = lat
oil_price_top10['lng'] = lng
oil_price_top10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#           Oil_store                         주소      가격 셀프     상표    구  \
# 305           서남주유소       서울 중구 통일로 30 (봉래동1가)  2040.0  N  SK에너지   중구
# 500         뉴서울(강남)       서울 강남구 언주로 716 (논현동)  1998.0  N  SK에너지  강남구
# 304           필동주유소   서울특별시 중구  퇴계로 196 (필동2가)  1979.0  N  GS칼텍스   중구
# 293  (주)대양씨앤씨 사직주유소        서울 종로구 사직로 65 (사직동)  1978.0  N  GS칼텍스  종로구
# 153           삼선주유소           서울 성북구  창경궁로 324  1975.0  N  S-OIL  성북구
# 303     SC(주) 역전주유소  서울특별시 중구  퇴계로 15 (남대문로5가)  1969.0  N  GS칼텍스   중구
# 302           장충주유소     서울 중구 장충단로 202 (장충동1가)  1969.0  N  SK에너지   중구
# 301           초동주유소        서울시 중구 마른내로 31 (초동)  1969.0  N  GS칼텍스   중구
# 114           양재주유소      서울 서초구 바우뫼로 178 (양재동)  1969.0  N  SK에너지  서초구
# 267            에너비스       서울 용산구 한남대로 82 (한남동)  1968.0  N  SK에너지  용산구
#
#            lat         lng
# 305  37.558348  126.972090
# 500  37.517636  127.035756
# 304  37.560850  126.993653
# 293  37.574464  126.966618
# 153  37.587908  127.005575
# 303  37.557001  126.974495
# 302  37.562719  127.007010
# 301  37.564944  126.991136
# 114  37.478071  127.039610
# 267  37.535952  127.006130

# %%
from tqdm import tqdm_notebook

lat = []
lng = []

for n in tqdm_notebook(oil_price_bottom10.index):
    try:
        tmp_add = oil_price_bottom10['주소'][n].split('(')[0]
        tmp_map = gmaps.geocode(tmp_add)

        tmp_loc = tmp_map[0]['geometry']
        lat.append(tmp_loc['location']['lat'])
        lng.append(tmp_loc['location']['lng'])
        
    except:
        lat.append(np.nan)
        lng.append(np.nan)
        print("Here is nan !")
    
oil_price_bottom10['lat'] = lat
oil_price_bottom10['lng'] = lng
oil_price_bottom10
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
#                Oil_store                          주소      가격 셀프      상표    구  \
# 268                수색뉴타운    서울특별시 은평구  수색로 350 (수색동)  1285.0  Y   GS칼텍스  은평구
# 269               타이거주유소        서울 은평구 수색로 188 (증산동)  1285.0  Y   SK에너지  은평구
# 270    (주)명연에너지 수색훼미리주유소        서울 은평구 수색로 236 (수색동)  1285.0  Y  현대오일뱅크  은평구
# 76              만남의광장주유소  서울 서초구 양재대로12길 73-71 (원지동)  1294.0  Y  알뜰(ex)  서초구
# 271                다회주유소        서울 은평구 증산로 441 (신사동)  1294.0  Y   S-OIL  은평구
# 322  KH에너지(주)직영 KH외발산주유소              서울 강서구 방화대로 30  1295.0  Y   SK에너지  강서구
# 415                구광주유소   서울특별시 금천구  서부샛길 674 (가산동)  1295.0  N   S-OIL  금천구
# 323            강서오곡셀프주유소     서울특별시 강서구 벌말로 254 (오곡동)  1297.0  Y   SK에너지  강서구
# 306       (주)자연에너지 대창주유소        서울 중랑구 동일로 636 (면목동)  1297.0  N  현대오일뱅크  중랑구
# 443     SK네트웍스(주)도봉행복주유소    서울특별시 도봉구  도봉로 941 (도봉동)  1299.0  Y   SK에너지  도봉구
#
#            lat         lng
# 268  37.587107  126.887542
# 269  37.578424  126.902050
# 270  37.581122  126.897774
# 76   37.459906  127.042060
# 271  37.595592  126.914451
# 322  37.563325  126.815386
# 415  37.481968  126.875149
# 323  37.555284  126.768567
# 306  37.587170  127.080217
# 443  37.688335  127.045313

# %%
map = folium.Map(location=[37.5202, 126.975], zoom_start=10.5)

for n in oil_price_top10.index:
    if pd.notnull(oil_price_top10['lat'][n]):
        folium.CircleMarker([oil_price_top10['lat'][n], oil_price_top10['lng'][n]], 
                                  radius=15, color='#CD3181', 
                                  fill_color='#CD3181',
                                  fill=True).add_to(map)
    
for n in oil_price_bottom10.index:
    if pd.notnull(oil_price_bottom10['lat'][n]): 
        folium.CircleMarker([oil_price_bottom10['lat'][n], 
                                  oil_price_bottom10['lng'][n]], 
                                  radius=15, color='#3186cc', 
                                  fill_color='#3186cc',
                                  fill=True).add_to(map)
        
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
oil_price_bottom10.head()
# Out:
#              Oil_store                          주소      가격 셀프      상표    구  \
# 268              수색뉴타운    서울특별시 은평구  수색로 350 (수색동)  1285.0  Y   GS칼텍스  은평구
# 269             타이거주유소        서울 은평구 수색로 188 (증산동)  1285.0  Y   SK에너지  은평구
# 270  (주)명연에너지 수색훼미리주유소        서울 은평구 수색로 236 (수색동)  1285.0  Y  현대오일뱅크  은평구
# 76            만남의광장주유소  서울 서초구 양재대로12길 73-71 (원지동)  1294.0  Y  알뜰(ex)  서초구
# 271              다회주유소        서울 은평구 증산로 441 (신사동)  1294.0  Y   S-OIL  은평구
#
#            lat         lng
# 268  37.587107  126.887542
# 269  37.578424  126.902050
# 270  37.581122  126.897774
# 76   37.459906  127.042060
# 271  37.595592  126.914451
